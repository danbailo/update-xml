# %%
import xmltodict

# %%
with open('NF_000338513_ChaveAcesso_35190902645941000108550010003385131455009580.xml') as fd:
    doc = xmltodict.parse(fd.read())

# %%
doc["nfeProc"]["NFe"]["infNFe"]
# Out:
# OrderedDict([('@Id', 'NFe35190902645941000108550010003385131455009580'),
#              ('@versao', '4.00'),
#              ('ide',
#               OrderedDict([('cUF', '35'),
#                            ('cNF', '45500958'),
#                            ('natOp', 'REMESSA DE VASILHAME OU SACARIA'),
#                            ('mod', '55'),
#                            ('serie', '1'),
#                            ('nNF', '338513'),
#                            ('dhEmi', '2019-09-10T19:35:22-03:00'),
#                            ('dhSaiEnt', '2019-09-10T19:35:32-03:00'),
#                            ('tpNF', '1'),
#                            ('idDest', '1'),
#                            ('cMunFG', '3554102'),
#                            ('tpImp', '1'),
#                            ('tpEmis', '1'),
#                            ('cDV', '0'),
#                            ('tpAmb', '1'),
#                            ('finNFe', '1'),
#                            ('indFinal', '0'),
# ...
